# %% [markdown]
# # Template for the new notebook

# %% [markdown]
# ## Create your .env file
# * In the github repo we have included a file named .env.example
# * Rename that file to .env file and here is where you will add your confidential api keys. Remember to include:
# * OPENAI_API_KEY=your_openai_api_key
# * LANGCHAIN_TRACING_V2=true
# * LANGCHAIN_ENDPOINT=https://api.smith.langchain.com
# * LANGCHAIN_API_KEY=your_langchain_api_key
# * LANGCHAIN_PROJECT=your_project_name

# %% [markdown]
# We will call this LangSmith project **projectName**.

# %% [markdown]
# ## Track operations
# From now on, we can track the operations **and the cost** of this project from LangSmith:
# * [smith.langchain.com](https://smith.langchain.com)

# %% [markdown]
# ## Connect with the .env file located in the same directory of this notebook

# %% [markdown]
# If you are using the pre-loaded poetry shell, you do not need to install the following package because it is already pre-loaded for you:

# %%
#pip install python-dotenv

# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())
openai_api_key = os.environ["OPENAI_API_KEY"]
print ("openai_api_key", openai_api_key)
# Out:
# openai_api_key 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

# %% [markdown]
# ## Create a new Chat Model
# * In this project we will use the gpt-3.5-turbo Foundation LLM from OpenAI.
# * [Here](https://platform.openai.com/docs/models/overview) you can take a look at the different models and prices of OpenAI.

# %% [markdown]
# If you are using the pre-loaded poetry shell, you do not need to install the following package because it is already pre-loaded for you:

# %%
from langchain_openai import ChatOpenAI

chatModel = ChatOpenAI(model="gpt-3.5-turbo")

# %% [markdown]
# ## Ask the first question to the Chat Model

# %%
question = "help me in preparing my schedule and fight through my internal resistance I am struggling to set routine and find motivation for coding and working on my career I find self attracted to short term pleasures , I eat alot and sleep more than required when I feel work to do I feel sleepy with hope that i will start after waking up"

response = chatModel.invoke(question)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 response = chatModel.invoke(question)
#
# NameError: name 'question' is not defined

# %%
print(response.content)
# Out:
# It sounds like you are experiencing a lack of motivation and difficulty in setting a routine for coding and working on your career. Here are some tips to help you overcome your internal resistance and create a schedule that works for you:
#
# 1. Set clear and specific goals: Before you start working on coding or your career, take some time to define your goals. This will give you a clear direction and purpose, which can help increase your motivation and focus.
#
# 2. Break your work into smaller tasks: Sometimes, the thought of starting a big project can be overwhelming and lead to procrastination. Break your work into smaller, manageable tasks and work on them one at a time. This can help make the process more manageable and less daunting.
#
# 3. Create a schedule: Set aside dedicated time each day to work on coding and your career. Create a schedule that works for you, whether it's a few hours in the morning or evening, or even small chunks of time throughout the day. Stick to your schedule as much as possible to build a routine.
#
# 4. Eliminate distractions: Identify any distractions that may be hindering your productivity, such as social media, television, or unhealthy eating habits. Set boundaries and create a conducive work environment free from distractions.
#
# 5. Find a support system: Surround yourself with supportive and like-minded individuals who can help keep you accountable and motivated. Join coding communities, attend networking events, or find a mentor who can provide guidance and encouragement.
#
# 6. Practice self-care: Take care of your physical and mental well-being by getting enough rest, eating healthy, and engaging in regular exercise. Taking care of yourself can help improve your focus, energy levels, and overall motivation.
#
# Remember that change takes time and effort, so be patient with yourself as you work towards establishing a routine and overcoming your internal resistance. Stay focused on your goals and keep pushing forward, even when it feels challenging. You have the potential to succeed in coding and your career – believe in yourself and stay committed to your journey.

# %% [markdown]
# ## How to execute the code from Visual Studio Code
# * In Visual Studio Code, see the file 001-file-name.py
# * In terminal, make sure you are in the directory of the file and run:
#     * python 001-file-name.py

# %%
# Out:
#   Cell In[11], line 1
#     poetry install
#            ^
# SyntaxError: invalid syntax
